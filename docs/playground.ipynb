# %%
import json
import inspect
import ast
import zlib
import hashlib
import time
import os

multirangers = lambda *args: [x for y in [list(range(*z)) for z in args] for x in y]


class RattishMeaning:
    def __init__(self):
        pass
    def __getitem__(self, key=None):
        if key is None or key not in self.charmap:
            raise KeyError(self, key)
        return self.charmap[key]


class RattishMemory:
    def __init__(self):
        pass



class RattishProcessor:

    standard_namespace = [(chr(char),hex(char), char) for char in multirangers((33,47),(58,64),(91,96),(123,126))]

    memory = None
    context = None
    charmap = None

    def __init__(self, shared_inherits=None):
        self.charmap={}
        # if shared_inherits is not None:
        #     if "memory" in shared_inherits:

        #     if "charmap" in shared_inherits:

        #     if "context" in shared_inherits:
        #         self.

        self.standart_checkup()
        #print("namespace")
        self[">"] = lambda core, input_args: core.output_handler(input_args) 
        self["<"] = lambda core, input_args: core.input_handler(input_args)
        self["$"] = lambda core, input_args: core.point_to_context(input_args)
        self["="] = lambda core, input_args: core.assign_context_value(input_args)
        self["@"] = lambda core, input_args: core.load_import(input_args)
        
    def standart_checkup(self):
        if self.memory is None or not len(self.memory):
            self.memory = {"UNIXUSAT": int(time.time()*1000)}
        if self.context is None or not self.context.strip():
            self.context = next(iter(self.memory))
            

    def output_handler(self, string):
        if string.strip():
            print(string.strip())
        else:
            print(self.memory[self.context])

    def input_handler(self, string):
        
        if string.strip():
            self.memory[self.context] = input(string)
        else:
            #self.__class__()
            self.memory[self.context] = input(self.memory[self.context])

    def point_to_context(self, string):
        if string.strip():
            self.context=string.strip()
        else:
            self.memory["LAST_CONTEXT"] = self.context
            self.context = "LAST_CONTEXT"
        #if not name is None:
            
        #return (self.context, name, self.context in self.memory)
    def load_import(self, string):
        to_be_imported = ""
        if string.strip():
            to_be_imported = string.strip()
        else:
            to_be_imported = self.memory[self.context]
        if os.path.exists(to_be_imported):
            with open(to_be_imported) as f:
                self + f.read()

    def assign_context_value(self, string):
        if string.strip():
            self.memory[self.context] = string
        else:
            del self.memory[self.context]

    def __getitem__(self, key=None):
        if key is None or key not in self.charmap:
            raise KeyError(self, key)
        return self.charmap[key]
    
    def __setitem__(self, key=None, instruction=None):
        if key is None or instruction is None:
            raise IsADirectoryError(self, key, instruction, "key and data must BE")

        self.charmap[key] = instruction

    def __str__(self):
        return json.dumps({
            x: "->".join([
                str(inspect.signature(self.charmap[x])),
                str(zlib.adler32(str.encode(ast.dump(ast.parse(inspect.getsource(self.charmap[x]))))))
            ]) for x in self.charmap
        }, indent=4)

    def __repr__(self):
        return json.dumps([
            {
                "command": x,
                "signature": str(inspect.signature(self.charmap[x])),
                "adler32":zlib.adler32(str.encode(ast.dump(ast.parse(inspect.getsource(self.charmap[x]))))),
                "ASDL": ast.dump(ast.parse(inspect.getsource(self.charmap[x])), indent=4).split("\n")
            } for x in self.charmap
        ], indent=4)
    
    def __add__(self, added=None):
        #print(json.dumps(added))
        for line in added.split("\n"):
            if line.strip():
                if line[0] in self.charmap:
                    self.standart_checkup()
                    self.charmap[line[0]](self, line[1:])
        
        #return repr(self)

# %%
interpreter = RattishCore()

#print(interpreter)

#interpreter["<"]=lambda core, input : core.output_handler(input)

#print(interpreter)

#print(repr(interpreter))

#print(interpreter["<"])

rattish_code = """
>Hello World
"""

#print( interpreter + rattish_code )

interpreter + rattish_code
# Out:
# Hello World

# %%
rattish_code = """
>standard sample
>
$
>
$data
=lorem ipsum
>
<data
>
$
>
$
>
@payload.rat
"""

#print( interpreter + rattish_code )

interpreter + rattish_code
# Out:
# standard sample
# LAST_CONTEXT
# LAST_CONTEXT
# lorem ipsum
# ssss
# data
# LAST_CONTEXT
# THIS IS LOAD
# LIKE A GOD
# BUT AS BOT

# %%
import unicodedata

multirangers = lambda *args: [x for y in [list(range(*z)) for z in args] for x in y]
    
meaningspace = [(chr(char),hex(char), char, unicodedata.name(chr(char)), unicodedata.name(chr(char)).lower().replace(" ","_")) for char in multirangers((32,48),(58,65),(91,97),(123,127))]

meaningspace
# Out:
# [(' ', '0x20', 32, 'SPACE', 'space'),
#  ('!', '0x21', 33, 'EXCLAMATION MARK', 'exclamation_mark'),
#  ('"', '0x22', 34, 'QUOTATION MARK', 'quotation_mark'),
#  ('#', '0x23', 35, 'NUMBER SIGN', 'number_sign'),
#  ('$', '0x24', 36, 'DOLLAR SIGN', 'dollar_sign'),
#  ('%', '0x25', 37, 'PERCENT SIGN', 'percent_sign'),
#  ('&', '0x26', 38, 'AMPERSAND', 'ampersand'),
#  ("'", '0x27', 39, 'APOSTROPHE', 'apostrophe'),
#  ('(', '0x28', 40, 'LEFT PARENTHESIS', 'left_parenthesis'),
#  (')', '0x29', 41, 'RIGHT PARENTHESIS', 'right_parenthesis'),
#  ('*', '0x2a', 42, 'ASTERISK', 'asterisk'),
#  ('+', '0x2b', 43, 'PLUS SIGN', 'plus_sign'),
#  (',', '0x2c', 44, 'COMMA', 'comma'),
#  ('-', '0x2d', 45, 'HYPHEN-MINUS', 'hyphen-minus'),
#  ('.', '0x2e', 46, 'FULL STOP', 'full_stop'),
#  ('/', '0x2f', 47, 'SOLIDUS', 'solidus'),
#  (':', '0x3a', 58, 'COLON', 'colon'),
#  (';', '0x3b', 59, 'SEMICOLON', 'semicolon'),
#  ('<', '0x3c', 60, 'LESS-THAN SIGN', 'less-than_sign'),
#  ('=', '0x3d', 61, 'EQUALS SIGN', 'equals_sign'),
#  ('>', '0x3e', 62, 'GREATER-THAN SIGN', 'greater-than_sign'),
#  ('?', '0x3f', 63, 'QUESTION MARK', 'question_mark'),
#  ('@', '0x40', 64, 'COMMERCIAL AT', 'commercial_at'),
#  ('[', '0x5b', 91, 'LEFT SQUARE BRACKET', 'left_square_bracket'),
#  ('\\', '0x5c', 92, 'REVERSE SOLIDUS', 'reverse_solidus'),
#  (']', '0x5d', 93, 'RIGHT SQUARE BRACKET', 'right_square_bracket'),
#  ('^', '0x5e', 94, 'CIRCUMFLEX ACCENT', 'circumflex_accent'),
#  ('_', '0x5f', 95, 'LOW LINE', 'low_line'),
#  ('`', '0x60', 96, 'GRAVE ACCENT', 'grave_accent'),
#  ('{', '0x7b', 123, 'LEFT CURLY BRACKET', 'left_curly_bracket'),
#  ('|', '0x7c', 124, 'VERTICAL LINE', 'vertical_line'),
#  ('}', '0x7d', 125, 'RIGHT CURLY BRACKET', 'right_curly_bracket'),
#  ('~', '0x7e', 126, 'TILDE', 'tilde')]

# %%
len(meaningspace)
# Out:
# 33

# %%
# meaningspace = "default"

# definitions = f"""
# class {meaningspace.capitalize()}RattishMeanings(RattishMeanings):
#     core = None
#     charmap = None
# """

# assignings = """
#     def assign_meanings(self):
        
# """


standard_command = """
    if string.strip():
        pass #core.blank()
    else:
        pass #core.blank() 

"""

#definitions=""


import unicodedata
import pathlib
import os
import hashlib
import zlib


multirangers = lambda *args: [x for y in [list(range(*z)) for z in args] for x in y]

rattish_rootdir = os.path.dirname(__file__)

def init_meaningspace(meaningspace):
    
    spacedir = pathlib.Path(rattish_rootdir) / "meaningspace"

    if not os.path.exists(spacedir.resolve()):
        os.mkdir(spacedir.resolve())

    standard_space = [(chr(char),hex(char), char, unicodedata.name(chr(char)), unicodedata.name(chr(char)).lower().replace(" ","_")) for char in multirangers((32,48),(58,65),(91,97),(123,127))]

    for command in standard_space:
        #py_file= spacedir / f"{zlib.adler32(f"{meaningspace}___{x[4]}")}.py"
        py_file = spacedir / f"{meaningspace}___{command[4]}.py"
        with open(py_file.resolve(), "w") as codefile:
            codefile.write(f"\"\"\"Rattish initialized file ;; meaning_space={meaningspace} , command_char='{command[3]}' \"\"\"\n")
            codefile.write("\n# RATTISH PROJECT - https://github.com/rattish \n\n")
            codefile.write("def __init__(core, string):\n")
            codefile.write(standard_command)
        #definitions+=
        #definitions+=f"{x[4]}(core, string)"

        #definitions+=":\n"
        #definitions+=standard_command


    with open(f"./meaningspace/{meaningspace}.json", "w") as manifest_file:
        manifest_file.write(
            json.dumps({
                x[4]:{
                    "asciicode":x[2],
                    "docs":(pathlib.Path(rattish_rootdir) / "docs" / "commands" / meaningspace / f"{x[1]}.md").resolve(),
                    #"meanings_file":f"./meaningspace/{meaningspace}.py",
                    "meanings_file":(spacedir / f"{meaningspace}___{x[4]}.py").resolve(),
                    #"def":f"{x[4]}(core, string)",
                    "def":"__init__(core, string)",
                    "label":x[3],
                    "call_char":x[0]
                } for x in standard_space
            }, indent=4)
        )
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[103], line 35
#      30 import zlib
#      33 multirangers = lambda *args: [x for y in [list(range(*z)) for z in args] for x in y]
# ---> 35 rattish_rootdir = os.path.dirname(__file__)
#      37 def init_meaningspace(meaningspace):
#      39     spacedir = pathlib.Path(rattish_rootdir) / "meaningspace"
#
# NameError: name '__file__' is not defined

# %%
# %pip install .. --force-reinstall --upgrade --no-deps --no-cache-dir
from importlib import reload  # Python 3.4+

import rattish

rattish = reload(rattish)


#rattish.init_meaningspace("default")

# %%
import rattish
import pathlib

#str(pathlib.Path("../src/rattish").resolve())


#print(rattish)

rattish.init_meaningfile("default", str(pathlib.Path("../src/rattish").resolve()))

# %%
import rattish

interpreter = rattish.RattishProcessor()

#print(interpreter)

#interpreter["<"]=lambda core, input : core.output_handler(input)

#print(interpreter)

#print(repr(interpreter))

#print(interpreter["<"])

rattish_code = """
>Hello World
"""

#print( interpreter + rattish_code )

interpreter + rattish_code
